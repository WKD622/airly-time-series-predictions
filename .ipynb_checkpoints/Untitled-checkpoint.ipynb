# %% [markdown]
# # Szeregi czasowe
#
# Antoni Pięta
#
# Jaub Ziarko

# %%
from pandas import read_csv
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from pmdarima.arima import auto_arima
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %% [markdown]
# ### Ładowanie datasetu

# %%
data_filename = 'result.csv'
dataset = read_csv(data_filename)

# %% [markdown]
# ### Klumny i przykładowane dane z datasetu

# %%
dataset.head(7)
# Out:
#          datetime_from  avg(pm10)  avg(humidity)
# 0  2020-03-07 20:00:00  61.372609      90.216522
# 1  2020-03-07 21:00:00  61.545652      92.691304
# 2  2020-03-07 22:00:00  64.220870      93.950000
# 3  2020-03-07 23:00:00  65.425217      94.855652
# 4  2020-03-08 00:00:00  65.676087      94.962609
# 5  2020-03-08 01:00:00  63.363913      95.100435
# 6  2020-03-08 02:00:00  60.751304      95.300000

# %% [markdown]
# ### Informacje o datasecie

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1330 entries, 0 to 1329
# Data columns (total 3 columns):
# datetime_from    1330 non-null object
# avg(pm10)        1330 non-null float64
# avg(humidity)    1330 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 31.3+ KB

# %% [markdown]
# ### Dodajemy kolumnę, która ma być używana do przewidywana - `actual`
#
# Progonzujemy dane na następne 12h, więc cofamy się o 12 stepów do tyłu dla kolumny actual

# %%
steps = -12
dataset_for_prediction = dataset.copy()
dataset_for_prediction['actual'] = dataset_for_prediction['avg(pm10)'].shift(steps)

# %%
dataset_for_prediction.tail(15)
# Out:
#             datetime_from  avg(pm10)  avg(humidity)     actual
# 1315  2020-05-01 15:00:00  13.741304      81.459130  43.017391
# 1316  2020-05-01 16:00:00  17.801739      79.116087  37.230000
# 1317  2020-05-01 17:00:00  24.442609      78.803043  31.349130
# 1318  2020-05-01 18:00:00  31.771304      80.290870        NaN
# 1319  2020-05-01 19:00:00  39.994348      84.018696        NaN
# 1320  2020-05-01 20:00:00  45.491739      87.036522        NaN
# 1321  2020-05-01 21:00:00  46.817826      88.330000        NaN
# 1322  2020-05-01 22:00:00  48.958261      88.827826        NaN
# 1323  2020-05-01 23:00:00  50.524783      88.843478        NaN
# 1324  2020-05-02 00:00:00  49.862609      89.211739        NaN
# 1325  2020-05-02 01:00:00  48.520870      90.402174        NaN
# 1326  2020-05-02 02:00:00  44.915217      91.183478        NaN
# 1327  2020-05-02 03:00:00  43.017391      91.420870        NaN
# 1328  2020-05-02 04:00:00  37.230000      91.488261        NaN
# 1329  2020-05-02 05:00:00  31.349130      89.939565        NaN

# %% [markdown]
# ### Usuwamy wiersze z wartościami NaN

# %%
dataset_for_prediction=dataset_for_prediction.dropna()
dataset_for_prediction.tail(15)
# Out:
#             datetime_from  avg(pm10)  avg(humidity)     actual
# 1303  2020-05-01 03:00:00  60.059130      94.754348  13.741304
# 1304  2020-05-01 04:00:00  59.406957      91.002609  17.801739
# 1305  2020-05-01 05:00:00  59.446522      86.716087  24.442609
# 1306  2020-05-01 06:00:00  58.550870      82.067391  31.771304
# 1307  2020-05-01 07:00:00  54.934783      74.292174  39.994348
# 1308  2020-05-01 08:00:00  46.197391      67.548696  45.491739
# 1309  2020-05-01 09:00:00  30.754348      65.757826  46.817826
# 1310  2020-05-01 10:00:00  24.793043      70.995217  48.958261
# 1311  2020-05-01 11:00:00  26.771304      80.428696  50.524783
# 1312  2020-05-01 12:00:00  26.576087      87.537826  49.862609
# 1313  2020-05-01 13:00:00  19.735217      88.373043  48.520870
# 1314  2020-05-01 14:00:00  10.544348      85.246522  44.915217
# 1315  2020-05-01 15:00:00  13.741304      81.459130  43.017391
# 1316  2020-05-01 16:00:00  17.801739      79.116087  37.230000
# 1317  2020-05-01 17:00:00  24.442609      78.803043  31.349130

# %% [markdown]
# ### Ustawiamy date jako index

# %%
dataset_for_prediction['datetime_from'] = pd.to_datetime(dataset_for_prediction['datetime_from'])
dataset_for_prediction.index = dataset_for_prediction['datetime_from']
dataset_for_prediction
# Out:
#                           datetime_from  avg(pm10)  avg(humidity)     actual
# datetime_from
# 2020-03-07 20:00:00 2020-03-07 20:00:00  61.372609      90.216522  61.695652
# 2020-03-07 21:00:00 2020-03-07 21:00:00  61.545652      92.691304  55.019565
# 2020-03-07 22:00:00 2020-03-07 22:00:00  64.220870      93.950000  51.896522
# 2020-03-07 23:00:00 2020-03-07 23:00:00  65.425217      94.855652  45.816087
# 2020-03-08 00:00:00 2020-03-08 00:00:00  65.676087      94.962609  46.008261
# ...                                 ...        ...            ...        ...
# 2020-05-01 13:00:00 2020-05-01 13:00:00  19.735217      88.373043  48.520870
# 2020-05-01 14:00:00 2020-05-01 14:00:00  10.544348      85.246522  44.915217
# 2020-05-01 15:00:00 2020-05-01 15:00:00  13.741304      81.459130  43.017391
# 2020-05-01 16:00:00 2020-05-01 16:00:00  17.801739      79.116087  37.230000
# 2020-05-01 17:00:00 2020-05-01 17:00:00  24.442609      78.803043  31.349130
#
# [1318 rows x 4 columns]

# %% [markdown]
# ### Rysowanie wykresów na podstawie danych

# %% [markdown]
# PM10

# %%
dataset_for_prediction['avg(pm10)'].plot(color='green', figsize=(15, 2))
plt.legend(['avg(pm10)'])
plt.title('PM10')
plt.show()

# %% [markdown]
# Humidity

# %%
dataset_for_prediction['avg(humidity)'].plot(color='blue', figsize=(15, 2))
plt.legend(['avg(humidity)'])
plt.title('Humidity')
plt.show()

# %% [markdown]
# ### Normalizacja danych wejściowych oraz target features

# %%
sc_in = MinMaxScaler(feature_range=(0, 1))
scaled_input = sc_in.fit_transform(dataset_for_prediction[['avg(pm10)', 'avg(humidity)']])
scaled_input = pd.DataFrame(scaled_input)
X = scaled_input
X
# Out:
#              0         1
# 0     0.359750  0.899432
# 1     0.360803  0.928042
# 2     0.377075  0.942594
# 3     0.384400  0.953064
# 4     0.385926  0.954300
# ...        ...       ...
# 1313  0.106492  0.878120
# 1314  0.050588  0.841976
# 1315  0.070034  0.798191
# 1316  0.094731  0.771104
# 1317  0.135124  0.767485
#
# [1318 rows x 2 columns]

# %%
sc_out = MinMaxScaler(feature_range=(0, 1))
scaler_output = sc_out.fit_transform(dataset_for_prediction[['actual']])
scaler_output = pd.DataFrame(scaler_output)
y = scaler_output
y
# Out:
#              0
# 0     0.361715
# 1     0.321108
# 2     0.302112
# 3     0.265128
# 4     0.266297
# ...        ...
# 1313  0.281580
# 1314  0.259648
# 1315  0.248105
# 1316  0.212903
# 1317  0.177133
#
# [1318 rows x 1 columns]

# %% [markdown]
# ### Zmiana nazw kolumn dla danych wejściowych i targetów

# %%
X.rename(columns={0: 'pm10', 1: 'humidity'}, inplace=True)
y.rename(columns={0: 'pm10 prediction'}, inplace=True)
y.index=dataset_for_prediction.index
X.index=dataset_for_prediction.index

# %%
X
# Out:
#                          pm10  humidity
# datetime_from
# 2020-03-07 20:00:00  0.359750  0.899432
# 2020-03-07 21:00:00  0.360803  0.928042
# 2020-03-07 22:00:00  0.377075  0.942594
# 2020-03-07 23:00:00  0.384400  0.953064
# 2020-03-08 00:00:00  0.385926  0.954300
# ...                       ...       ...
# 2020-05-01 13:00:00  0.106492  0.878120
# 2020-05-01 14:00:00  0.050588  0.841976
# 2020-05-01 15:00:00  0.070034  0.798191
# 2020-05-01 16:00:00  0.094731  0.771104
# 2020-05-01 17:00:00  0.135124  0.767485
#
# [1318 rows x 2 columns]

# %%
y
# Out:
#                      pm10 prediction
# datetime_from
# 2020-03-07 20:00:00         0.361715
# 2020-03-07 21:00:00         0.321108
# 2020-03-07 22:00:00         0.302112
# 2020-03-07 23:00:00         0.265128
# 2020-03-08 00:00:00         0.266297
# ...                              ...
# 2020-05-01 13:00:00         0.281580
# 2020-05-01 14:00:00         0.259648
# 2020-05-01 15:00:00         0.248105
# 2020-05-01 16:00:00         0.212903
# 2020-05-01 17:00:00         0.177133
#
# [1318 rows x 1 columns]

# %% [markdown]
# ### Podział datasetu na dane treningowe i testowe

# %%
train_size = int(len(dataset) * 0.7)
test_size = int(len(dataset)) - train_size

train_X, train_y = X[:train_size].dropna(), y[:train_size].dropna()
test_X, test_y = X[train_size:].dropna(), y[train_size:].dropna()

# %% [markdown]
# ### Dekompoyzcja szeregu czasowego na trend, sezonowość/cykliczność, szum

# %%
seas_d=sm.tsa.seasonal_decompose(X['pm10'],model='add',period=55);
fig=seas_d.plot()
fig.set_figheight(10)
fig.set_figwidth(16)
plt.show()

# %% [markdown]
# Additive model = Trend + Seasonality + Random Noise

# %% [markdown]
# ### Sprawdzamy stacjonarość danych poprzez Augmented Dickey Fuller(ADF) test

# %% [markdown]
# Jeśli sprawimy że dane będą stacjonare to model będzie wykonywał przewidywania na podstawie tego że średnia oraz wariancją będą takie są przez przyszłe okresy.

# %%
def test_adf(series, title=''):
    dfout={}
    dftest=sm.tsa.adfuller(series.dropna(), autolag='AIC', regression='ct')
    for key,val in dftest[4].items():
        dfout[f'critical value ({key})']=val
    if dftest[1]<=0.05:
        print("Strong evidence against Null Hypothesis")
        print("Reject Null Hypothesis - Data is Stationary")
        print("Data is Stationary", title)
    else:
        print("Strong evidence for  Null Hypothesis")
        print("Accept Null Hypothesis - Data is not Stationary")
        print("Data is NOT Stationary for", title)

# %%
y_test=y['pm10 prediction'][:train_size].dropna()
test_adf(y_test, 'pm10')
# Out:
# Strong evidence for  Null Hypothesis
# Accept Null Hypothesis - Data is not Stationary
# Data is NOT Stationary for pm10

# %% [markdown]
# ### Dane stacjonarne - różnicowanie

# %%
test_adf(y_test.diff(), 'pm10')
# Out:
# Strong evidence against Null Hypothesis
# Reject Null Hypothesis - Data is Stationary
# Data is Stationary pm10

# %% [markdown]
# ### Budowanie modelu
#
# ACF plot: wykres słupkowy współczynników korelacji między szeregiem czasowym a jego własnym opóźnieniem
#
# PACF plot: wykres słupkowy współczynników częściowej korelacji między szeregiem czasowym a jego własnym opóźnieniem

# %%
fig,ax= plt.subplots(2,1, figsize=(10,5))
fig=sm.tsa.graphics.plot_acf(y_test, lags=50, ax=ax[0])
fig=sm.tsa.graphics.plot_pacf(y_test, lags=50, ax=ax[1])
plt.show()

# %% [markdown]
# ### Funkcja auto_arima która dobiera najlepsze parametry modelu ARIMA do szeregu czasowego.
#
# Losowo wybiera i sprawdza kolejne paraemtry dobierając w ten sposób te najlepsze. Próbuje zminimalizować partykę AIC (Akaike Information Criterion) - dobiera parametry dla ktorych jest najmniejsza.

# %%
step_wise=auto_arima(train_y, 
 exogenous= train_X,
 start_p=1, start_q=1, 
 max_p=7, max_q=7, 
 d=1, max_d=7,
 trace=True, 
 error_action='ignore', 
 suppress_warnings=True, 
 stepwise=True)
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA(1,1,1)x(0,0,0,0) [intercept=True]; AIC=-3422.130, BIC=-3393.126, Time=0.725 seconds
# Fit ARIMA(0,1,0)x(0,0,0,0) [intercept=True]; AIC=-3354.538, BIC=-3335.201, Time=0.123 seconds
# Fit ARIMA(1,1,0)x(0,0,0,0) [intercept=True]; AIC=-3412.550, BIC=-3388.379, Time=0.437 seconds
# Fit ARIMA(0,1,1)x(0,0,0,0) [intercept=True]; AIC=-3404.819, BIC=-3380.649, Time=0.745 seconds
# Fit ARIMA(0,1,0)x(0,0,0,0) [intercept=False]; AIC=-3356.538, BIC=-3342.035, Time=0.363 seconds
# Fit ARIMA(2,1,1)x(0,0,0,0) [intercept=True]; AIC=-3420.933, BIC=-3387.095, Time=0.853 seconds
# Fit ARIMA(1,1,2)x(0,0,0,0) [intercept=True]; AIC=-3401.572, BIC=-3367.734, Time=0.835 seconds
# Fit ARIMA(0,1,2)x(0,0,0,0) [intercept=True]; AIC=-3418.145, BIC=-3389.140, Time=0.590 seconds
# Fit ARIMA(2,1,0)x(0,0,0,0) [intercept=True]; AIC=-3422.597, BIC=-3393.592, Time=0.671 seconds
# Fit ARIMA(3,1,0)x(0,0,0,0) [intercept=True]; AIC=-3421.159, BIC=-3387.320, Time=0.833 seconds
# Fit ARIMA(3,1,1)x(0,0,0,0) [intercept=True]; AIC=-3419.173, BIC=-3380.500, Time=0.966 seconds
# Total fit time: 7.150 seconds

# %%
step_wise.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  930
# Model:               SARIMAX(2, 1, 0)   Log Likelihood                1717.298
# Date:                Sun, 03 May 2020   AIC                          -3422.597
# Time:                        16:28:18   BIC                          -3393.592
# Sample:                    03-07-2020   HQIC                         -3411.534
#                          - 04-15-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept  -8.415e-06      0.001     -0.007      0.995      -0.003       0.003
# pm10          -0.0272      0.121     -0.225      0.822      -0.265       0.210
# humidity       0.4386      0.052      8.490      0.000       0.337       0.540
# ar.L1          0.6824      0.118      5.806      0.000       0.452       0.913
# ar.L2         -0.1669      0.069     -2.433      0.015      -0.301      -0.032
# sigma2         0.0015   4.22e-05     34.339      0.000       0.001       0.002
# ===================================================================================
# Ljung-Box (Q):                      143.58   Jarque-Bera (JB):               608.95
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.77   Skew:                            -0.37
# Prob(H) (two-sided):                  0.02   Kurtosis:                         6.90
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# Zasugerowany został SARIMAX oraz wartości dla p,d,q wynoszące odpowiednio 2,1,0.

# %% [markdown]
# ### Trenowanie modelu

# %%
model = SARIMAX(train_y, exog=train_X, order=(2,1,0), enforce_invertibility=False, enforce_stationarity=False)
# Out:
# /usr/local/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)

# %%
results = model.fit()

# %% [markdown]
# ### Predykcja

# %% [markdown]
# predict

# %%
predictions= results.predict(start=train_size, end=train_size+test_size+(steps)-1,exog=test_X)

# %%
forecast_1= results.forecast(steps=test_size-1, exog=test_X)

# %%
act= pd.DataFrame(scaler_output.iloc[train_size:, 0])

# %%
act
# Out:
#                      pm10 prediction
# datetime_from
# 2020-04-15 14:00:00         0.115182
# 2020-04-15 15:00:00         0.126191
# 2020-04-15 16:00:00         0.186660
# 2020-04-15 17:00:00         0.271447
# 2020-04-15 18:00:00         0.418768
# ...                              ...
# 2020-05-02 00:00:00         0.281580
# 2020-05-02 01:00:00         0.259648
# 2020-05-02 02:00:00         0.248105
# 2020-05-02 03:00:00         0.212903
# 2020-05-02 04:00:00         0.177133
#
# [399 rows x 1 columns]

# %%
predictions=pd.DataFrame(predictions)
predictions.reset_index(drop=True, inplace=True)
predictions.index=test_X.index
predictions['actual'] = act['pm10 prediction']
predictions.rename(columns={0:'Pred'}, inplace=True)

# %%
predictions['actual'].plot(figsize=(20,8), legend=True, color='blue')
predictions['Pred'].plot(legend=True, color='red', figsize=(20,8))
